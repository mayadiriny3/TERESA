# %% [markdown]
#  <img src="https://drive.google.com/uc?id=167V7lh-ugAER9SWiARHDQcG2KydaT-J5" width="150" align="center">

# %% [markdown]
# # **Problemario**

# %% [markdown]
# * **Nombre del alumno: TERESA BARRERA ANGELES.**
#
# * **Asignatura: Matemáticas Aplicadas a Comunicaciones**
#
# * **Tema: TRANSFORMADA DE LAPLACE Y LA INVERSA DE LA TRANSFROMADA DE LAPLACE**

# %% [markdown]
# **Fecha de entrega: 20-10-2022**
#
# **TEMA:Transformada de Laplace**
#
# **TEMAS:**
#
# * 2.1 Definición y propiedades de la transformada de Laplace
# * 2.2 Condiciones suficientes de existencia para la transformada de Laplace
# * 2.3 Tranformada de Laplace
# * 2.4 Transformada inversa
# * 2.5 Transformada de derivadas (Teorema)
# * 2.6 Tranformada de diferenciales (Teorema)
# * 2.7 Teorema de consolación
# * 2.8 Transformada de Laplace de una función periodica
# * 2.9 Solución de ecuación diferenciales

# %% [markdown]
# # **INSTRUCCIONES**
#
# Resuelva las siguientes funciones empleando alguno de los métodos revisados en clase:
# * **Transformada de Laplace**
# * **Transformada Inversa de la de Laplace**

# %% [markdown]
# # Tabla de contenidos
# * [EVIDENCIA DE FIRMA PARA VALIDAR SECCIÓN.](#EVIDENCIA-DE-FIRMA-PARA-VALIDAR-SECCIÓN.)
# * [SECCIÒN 1: TRANSFORMADA DE LAPLACE.](#SECCIÒN-1:-TRANSFORMADA-DE-LAPLACE.)
#     * [SECCIÒN 2: TRANSFORMADA INVERSA DE LAPLACE.](#SECCIÒN-2:-TRANSFORMADA-INVERSA-DE-LAPLACE.)
#     * [SECCIÒN 3: DERIVADA DE LA TRANSFORMADA DE LAPLACE.](#SECCIÒN-3:-DERIVADA-DE-LA-TRANSFORMADA-DE-LAPLACE.)
#     * [Referencias](#Referencias)

# %% [markdown]
# #### Librerias utilizadas

# %%
print('Librerias Cargadas....')
import sympy as sp
sympy.init_printing(use_latex= 'mathjax')
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Librerias Cargadas....

# %%
t = sympy.Symbol('t')
s = sympy.Symbol('s')
a = sympy.Symbol('a', real=True, positive=True)

# %% [markdown]
# # EVIDENCIA DE FIRMA PARA VALIDAR SECCIÒN.
#
# <img src="https://drive.google.com/uc?id=1HjFjstNDiJt9ipEZyhX6oXPOckXIFHPR" alt="" width="400" >

# %% [markdown]
# # SECCIÒN 1: TRANSFORMADA DE LAPLACE.

# %% [markdown]
# ##  1.- $\mathscr{L}\left\lbrace{1}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1HprPfJwgH5tfLNEnCWId50rRplPHx-zr" alt="" width="400" >

# %%
Function = (1)
Function
# Out:
# 1

# %%
FunctionLaplace = sp.laplace_transform(Function, t, s, noconds=True)
FunctionLaplace
# Out:
# 1
# ─
# s

# %% [markdown]
# ## 2.- $\mathscr{L}\left\lbrace{2}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1HuHQyFHRyfiGnB7LmPObpfT_5uGlq-R-" alt="" width="400" >

# %%
Function = (2)
Function
# Out:
# 2

# %%
FunctionLaplace = sp.laplace_transform(Function, t, s, noconds=True)
FunctionLaplace
# Out:
# 2
# ─
# s

# %% [markdown]
# ## 3.- $\mathscr{L}\left\lbrace{3}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1HzrxZA0avCaWjqpIr29Q4JM6L_mF1XGN" alt="" width="400" >

# %%
Function = (3)
Function
# Out:
# 3

# %%
FunctionLaplace = sp.laplace_transform(Function, t, s, noconds=True)
FunctionLaplace
# Out:
# 3
# ─
# s

# %% [markdown]
# ## 4.-  $\mathscr{L}\left\lbrace{{t}}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1I6p79-mEaVGkOl0s0UUXQyu-eIMjs5Rx" alt="" width="400" >

# %%
Function = (t)
Function
# Out:
# t

# %%
FunctionLaplace = sp.laplace_transform(Function, t, s, noconds=True)
FunctionLaplace
# Out:
# 1
# ──
#  2
# s

# %% [markdown]
# ## 5.-  $\mathscr{L}\left\lbrace{{t^2}}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1IAbV7sVAvBG79WxJ9zJMwoZ71M2j16o6" alt="" width="400" >

# %%
Function = (t**2)
Function
# Out:
#  2
# t

# %%
FunctionLaplace = sp.laplace_transform(Function, t, s, noconds=True)
FunctionLaplace
# Out:
# 2
# ──
#  3
# s

# %% [markdown]
# ##  6.- $\mathscr{L}\left\lbrace{{1+5t}}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1IBBdGstqgfnfNFZvB95b6GXRaRmOvf0f" alt="" width="400" >

# %%
Function =(1+(5*t))
Function
# Out:
# 5⋅t + 1

# %%
FunctionLaplace = sp.laplace_transform(Function, t, s, noconds=True)
FunctionLaplace
# Out:
# s + 5
# ─────
#    2
#   s

# %% [markdown]
# ## 7.- $\mathscr{L}\left\lbrace{{e^{-3t}}}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1IHjHSl7AlFttQWMHXmaV635VpW5v1FdB" alt="" width="400" >

# %%
Function =sp.exp(-3*t)
Function
# Out:
#  -3⋅t
# ℯ

# %%
FunctionLaplace = sp.laplace_transform(Function, t, s, noconds=True)
FunctionLaplace
# Out:
#   1
# ─────
# s + 3

# %% [markdown]
# ## 8.- $\mathscr{L}\left\lbrace{{sen(2t)}}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1IJPAjD6wUMtJdph2CM9uzgMKhXPC-gBx" alt="" width="400" >
# <img src="https://drive.google.com/uc?id=1IQSF5P8F03MJfAw_h0I4MH0MPr-ExfCC" alt="" width="400" >

# %%
Function =sp.sin(2*t)
Function
# Out:
# sin(2⋅t)

# %%
FunctionLaplace = sp.laplace_transform(Function, t, s, noconds=True)
FunctionLaplace
# Out:
#   2
# ──────
#  2
# s  + 4

# %% [markdown]
# ## 9.- $\mathscr{L}\left\lbrace{{cos^2(t)}}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1IWD93au6z_co6Jw507krC-7Tgz3n3QuL" alt="" width="400" >

# %%
Function =sp.cos(t)**2
Function
# Out:
#    2
# cos (t)

# %%
FunctionLaplace = sp.laplace_transform(Function, t, s, noconds=True)
FunctionLaplace
# Out:
#    2
#   s  + 2
# ──────────
#   ⎛ 2    ⎞
# s⋅⎝s  + 4⎠

# %% [markdown]
# ##  10.- $\mathscr{L^{-1}}\left\lbrace{5e^{-3t}-2sen(2t) }\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1IXPK2bwKCV4JantUs1WkcafrA1eClkaB" alt="" width="400" >

# %%
Function =(5*sp.exp(-3*t))-(2*sp.sinh(2*t))
Function
# Out:
#                   -3⋅t
# -2⋅sinh(2⋅t) + 5⋅ℯ

# %%
FunctionLaplace = sp.laplace_transform(Function, t, s, noconds=True)
FunctionLaplace
# Out:
#    2
# 5⋅s  - 4⋅s - 32
# ────────────────
#         ⎛ 2    ⎞
# (s + 3)⋅⎝s  - 4⎠

# %% [markdown]
# ## 11.- $\mathscr{L}\left\lbrace{{e^tsenh(t)}}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1IXqWKVYz5PGxzsS6nqNheyg1v0hO--qV" alt="" width="400" >

# %%
Function =sp.exp(t)*sp.sinh(t)
Function
# Out:
#  t
# ℯ ⋅sinh(t)

# %%
FunctionLaplace = sp.laplace_transform(Function, t, s, noconds=True)
FunctionLaplace
# Out:
#      1
# ────────────
#        2
# (s - 1)  - 1

# %% [markdown]
#  ##  12.- $\mathscr{L}\left\lbrace{\frac{1+cos(2t)}{2}}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1IY8vu5explWLQUq6fxakOPrVA3Fv61d3" alt="" width="400" >

# %%
Function = ( sp.cos(2*t)+1)/2
Function
# Out:
# cos(2⋅t)   1
# ──────── + ─
#    2       2

# %%
FunctionLaplace = sp.laplace_transform(Function, t, s, noconds=True)
FunctionLaplace
# Out:
#    2
#   s  + 2
# ──────────
#   ⎛ 2    ⎞
# s⋅⎝s  + 4⎠

# %% [markdown]
#  ## 13.- $\mathscr{L}\left\lbrace{t cos(t)}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1I_b3yEviBey0ciEHsVghcgw72KWvQoS8" alt="" width="400" >

# %%
Function = (t*sp.cos(t))
Function
# Out:
# t⋅cos(t)

# %%
FunctionLaplace = sp.laplace_transform(Function, t, s, noconds=True)
FunctionLaplace
# Out:
#      2
#     s  - 1
# ─────────────
#  4      2
# s  + 2⋅s  + 1

# %% [markdown]
# ##  14.- $\mathscr{L}\left\lbrace{{e^{-t}{sen(t)}}}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1Ieja5pYdWr3GSfQqTjBg5InWs370SOoa" alt="" width="400" >

# %%
Function = (sp.exp(-t)*sp.sin(t))
Function
# Out:
#  -t
# ℯ  ⋅sin(t)

# %%
FunctionLaplace = sp.laplace_transform(Function, t, s, noconds=True)
FunctionLaplace
# Out:
#      1
# ────────────
#        2
# (s + 1)  + 1

# %% [markdown]
# ##  15.- $\mathscr{L}\left\lbrace{{t^{3}}}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1IsAIwJZ7HdQu3l89pDW6eaRVeePVTLOF" alt="" width="400" >

# %%
Function = (t**3)
Function
# Out:
#  3
# t

# %%
FunctionLaplace = sp.laplace_transform(Function, t, s, noconds=True)
FunctionLaplace
# Out:
# 6
# ──
#  4
# s

# %% [markdown]
# # SECCIÒN 2: TRANSFORMADA INVERSA DE LAPLACE.

# %% [markdown]
# ## 1.- $\mathscr{L^{-1}}\left\lbrace{\frac {1}{s^4}}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1JvFCGSbhSYC-hlF_HZbfhcPpz5zRSu2j" alt="" width="400" >

# %%
FUNCTION = 1/(s**4)
FUNCTION
# Out:
# 1
# ──
#  4
# s

# %%
INVERSEFUNCTION = sympy.inverse_laplace_transform(FUNCTION, s, t)
INVERSEFUNCTION
# Out:
#  3
# t ⋅θ(t)
# ───────
#    6

# %% [markdown]
# ## 2.- $\mathscr{L^{-1}}\left\lbrace{\frac {1}{s^5}}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1Jvh38ZA60E3n3RpGZ7h-I9vUwrHa3dws" alt="" width="400" >

# %%
FUNCTION = 1/(s**5)
FUNCTION
# Out:
# 1
# ──
#  5
# s

# %%
INVERSEFUNCTION = sympy.inverse_laplace_transform(FUNCTION, s, t)
INVERSEFUNCTION
# Out:
#  4
# t ⋅θ(t)
# ───────
#    24

# %% [markdown]
# ## 3.- $\mathscr{L^{-1}}\left\lbrace{\frac {1}{s^2 +7}}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1K-b44V87HSM7XETbugBW1q54-UgRXJ22" alt="" width="400" >

# %%
FUNCTION = 1/(s**2+7)
FUNCTION
# Out:
#   1
# ──────
#  2
# s  + 7

# %%
INVERSEFUNCTION = sympy.inverse_laplace_transform(FUNCTION, s, t)
INVERSEFUNCTION
# Out:
# √7⋅sin(√7⋅t)⋅θ(t)
# ─────────────────
#         7

# %% [markdown]
# ## 4.- $\mathscr{L^{-1}}\left\lbrace{\frac {10s}{s^2 +16}}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1K702Hh9RZqlWoTf8f_ZWV5sQO40raZv_" alt="" width="400" >

# %%
FUNCTION =  10/(s**2+16)
FUNCTION
# Out:
#    10
# ───────
#  2
# s  + 16

# %%
INVERSEFUNCTION = sympy.inverse_laplace_transform(FUNCTION, s, t)
INVERSEFUNCTION
# Out:
# 5⋅sin(4⋅t)⋅θ(t)
# ───────────────
#        2

# %% [markdown]
# ## 5.- $\mathscr{L^{-1}}\left\lbrace{(\frac {2}{s}}-{\frac {1}{s^3})^2}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1KB0lZKkzlz7xksHE0HQgMT1L-9iXpuOc" alt="" width="400" >

# %%
FUNCTION = ((2/s) - (1/s**3))**2
FUNCTION
# Out:
#         2
# ⎛2   1 ⎞
# ⎜─ - ──⎟
# ⎜s    3⎟
# ⎝    s ⎠

# %%
INVERSEFUNCTION = sympy.inverse_laplace_transform(FUNCTION, s, t)
INVERSEFUNCTION
# Out:
#   ⎛ 4       2      ⎞
# t⋅⎝t  - 80⋅t  + 480⎠⋅θ(t)
# ─────────────────────────
#            120

# %% [markdown]
# ## 6.- $\mathscr{L^{-1}}\left\lbrace{\frac {s}{s^2+2s-3}}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1KH1kVVcS9KsxM-QumOxhZi8jzDk_2dvr" alt="" width="400" >

# %%
FUNCTION = s/(s**2+2*s-3)
FUNCTION
# Out:
#      s
# ────────────
#  2
# s  + 2⋅s - 3

# %%
INVERSEFUNCTION = sympy.inverse_laplace_transform(FUNCTION, s, t)
INVERSEFUNCTION
# Out:
# ⎛ 4⋅t    ⎞  -3⋅t
# ⎝ℯ    + 3⎠⋅ℯ    ⋅θ(t)
# ─────────────────────
#           4

# %% [markdown]
# ## 7.- $\mathscr{L^{-1}}\left\lbrace{\frac {1}{s^3+5s}}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1KHKczcdB7jV1X7wh062IP6r28zb3l7_T" alt="" width="400" >

# %%
FUNCTION = 1/(s**3+5*s)
FUNCTION
# Out:
#    1
# ────────
#  3
# s  + 5⋅s

# %%
INVERSEFUNCTION = sympy.inverse_laplace_transform(FUNCTION, s, t)
INVERSEFUNCTION
# Out:
# (1 - cos(√5⋅t))⋅θ(t)
# ────────────────────
#          5

# %% [markdown]
# ## 8.- $\mathscr{L^{-1}}\left\lbrace{\frac {s+1}{s^2-4s}}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1KIZGNtZyTf9S6TQ_5ZYcQlCCDPBn0Lp0" alt="" width="400" >

# %%
FUNCTION = (s+1)/(s**2-4*s)
FUNCTION
# Out:
#  s + 1
# ────────
#  2
# s  - 4⋅s

# %%
INVERSEFUNCTION = sympy.inverse_laplace_transform(FUNCTION, s, t)
INVERSEFUNCTION
# Out:
# ⎛   4⋅t    ⎞
# ⎝5⋅ℯ    - 1⎠⋅θ(t)
# ─────────────────
#         4

# %% [markdown]
# ## 9.- $\mathscr{L^{-1}}\left\lbrace{\frac{2s+5}{(s-3)^2}}\right\rbrace$

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1KLa-_1G050Tnj4WjQJ5Sti2CXt837C-x" alt="" width="400" >

# %%
FUNCTION = (2*s+5)/(s-3)**2
FUNCTION
# Out:
# 2⋅s + 5
# ────────
#        2
# (s - 3)

# %%
INVERSEFUNCTION = sympy.inverse_laplace_transform(FUNCTION, s, t)
INVERSEFUNCTION
# Out:
#             3⋅t
# (11⋅t + 2)⋅ℯ   ⋅θ(t)

# %% [markdown]
# # SECCIÒN 3: DERIVADA DE LA TRANSFORMADA DE LAPLACE.

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1KdmAQbAoIXo_ZjvIdRxMWuhmmuyAAcBI" alt="" width="400" >

# %%
t = sympy.symbols("t", positive=True)
y = sympy.Function("y")

s, Y = sympy.symbols("s, Y", real=True)

edo = y(t).diff(t) + 2*y(t)-13*sympy.sin(2*y(t))
sympy.Eq(edo,0)
# Out:
#                           d
# 2⋅y(t) - 13⋅sin(2⋅y(t)) + ──(y(t)) = 0
#                           dt

# %%
s, Y = sympy.symbols("s, Y", real=True)

# %%
L_edo = sympy.laplace_transform(edo, t, s)
sympy.Eq(L_edo,0)
# Out:
# s⋅LaplaceTransform(y(t), t, s) + 2⋅LaplaceTransform(y(t), t, s) - 13⋅LaplaceTr
# ansform(sin(2⋅y(t)), t, s) - y(0) = 0

# %%
def laplace_transform_derivatives(e):
    """
    Evalua las transformadas de Laplace de derivadas de funciones sin evaluar.
    """
    if isinstance(e, sympy.LaplaceTransform):
        if isinstance(e.args[0], sympy.Derivative):
            d, t, s = e.args 
            n = len(d.args) - 1
            return ((s**n) * sympy.LaplaceTransform(d.args[0], t, s) -
                    sum([s**(n-i) * sympy.diff(d.args[0], t, i-1).subs(t, 0)
                         for i in range(1, n+1)]))
        
    if isinstance(e, (sympy.Add, sympy.Mul)):
        t = type(e) 
        return t(*[laplace_transform_derivatives(arg) for arg in e.args])
    
    return e

# %%
L_edo_2 = laplace_transform_derivatives(L_edo)
sympy.Eq(L_edo_2,0)
# Out:
# s⋅LaplaceTransform(y(t), t, s) + 2⋅LaplaceTransform(y(t), t, s) - 13⋅LaplaceTr
# ansform(sin(2⋅y(t)), t, s) - y(0) = 0

# %%
L_edo_3 = L_edo_2.subs(sympy.laplace_transform(y(t), t, s), Y)
sympy.Eq(L_edo_3,0)
# Out:
# Y⋅s + 2⋅Y - 13⋅LaplaceTransform(sin(2⋅y(t)), t, s) - y(0) = 0

# %%
ics = {y(0): 6, y(t).diff(t).subs(t, 0): 0}
ics
# Out:
# ⎧         ⎛d       ⎞│      ⎫
# ⎨y(0): 6, ⎜──(y(t))⎟│   : 0⎬
# ⎩         ⎝dt      ⎠│t=0   ⎭

# %%
L_edo_4 = L_edo_3.subs(ics)

Y_sol = sympy.solve(L_edo_4, Y)
Y_sol
# Out:
# ⎡13⋅LaplaceTransform(sin(2⋅y(t)), t, s) + 6⎤
# ⎢──────────────────────────────────────────⎥
# ⎣                  s + 2                   ⎦

# %%
y_sol = sympy.inverse_laplace_transform(Y_sol[0], s, t)
y_sol
# Out:
#                           ⎛LaplaceTransform(sin(2⋅y(t)), t, s)            ⎞
# 13⋅InverseLaplaceTransform⎜───────────────────────────────────, s, t, None⎟ +
#                           ⎝               s + 2                           ⎠
#
#    -2⋅t
# 6⋅ℯ

# %%
y_sol.subs(t, 0), sympy.diff(y_sol).subs(t, 0)
# Out:
# ⎛                          ⎛LaplaceTransform(sin(2⋅y(0)), 0, s)            ⎞
# ⎜13⋅InverseLaplaceTransform⎜───────────────────────────────────, s, 0, None⎟ +
# ⎝                          ⎝               s + 2                           ⎠
#
#        ⎛d ⎛                       ⎛LaplaceTransform(sin(2⋅y(t)), t, s)
#  6, 13⋅⎜──⎜InverseLaplaceTransform⎜───────────────────────────────────, s, t,
#        ⎝dt⎝                       ⎝               s + 2
#
#     ⎞⎞⎞│        ⎞
# None⎟⎟⎟│    - 12⎟
#     ⎠⎠⎠│t=0     ⎠

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1Kj-xyiDfK4JZzpFPjimGa7yMod7Tigck" alt="" width="400" >

# %%
t = sympy.symbols("t", positive=True)
L = sympy.symbols("L", positive=True)
R = sympy.symbols("R", positive=True)
y = sympy.Function("y")

s, Y = sympy.symbols("s, Y", real=True)

edo = L*y(t).diff(t, t) + R*y(t).diff(t) - y(t) 
sympy.Eq(edo,0)
# Out:
#     2
#    d            d
# L⋅───(y(t)) + R⋅──(y(t)) - y(t) = 0
#     2           dt
#   dt

# %%
s, Y = sympy.symbols("s, Y", real=True)

# %%
L_edo = sympy.laplace_transform(edo, t, s)
sympy.Eq(L_edo, 0)
# Out:
#  2
# s ⋅LaplaceTransform(y(t), t, s) + s⋅LaplaceTransform(y(t), t, s) - s⋅y(0) - La
#
#
#                                     ⎛d       ⎞│
# placeTransform(y(t), t, s) - y(0) - ⎜──(y(t))⎟│    = 0
#                                     ⎝dt      ⎠│t=0

# %%
def laplace_transform_derivatives(e):
    """
    Evalua las transformadas de Laplace de derivadas de funciones sin evaluar.
    """
    if isinstance(e, sympy.LaplaceTransform):
        if isinstance(e.args[0], sympy.Derivative):
            d, t, s = e.args 
            n = len(d.args) - 1
            return ((s**n) * sympy.LaplaceTransform(d.args[0], t, s) -
                    sum([s**(n-i) * sympy.diff(d.args[0], t, i-1).subs(t, 0)
                         for i in range(1, n+1)]))
        
    if isinstance(e, (sympy.Add, sympy.Mul)):
        t = type(e) 
        return t(*[laplace_transform_derivatives(arg) for arg in e.args])
    
    return e

# %%
L_edo_2 = laplace_transform_derivatives(L_edo)
sympy.Eq(L_edo_2,0)
# Out:
#  2
# s ⋅LaplaceTransform(y(t), t, s) + s⋅LaplaceTransform(y(t), t, s) - s⋅y(0) - La
#
#
#                                     ⎛d       ⎞│
# placeTransform(y(t), t, s) - y(0) - ⎜──(y(t))⎟│    = 0
#                                     ⎝dt      ⎠│t=0

# %%
L_edo_3 = L_edo_2.subs(sympy.laplace_transform(y(t), t, s), Y)
sympy.Eq(L_edo_3,0)
# Out:
#    2                             ⎛d       ⎞│
# Y⋅s  + Y⋅s - Y - s⋅y(0) - y(0) - ⎜──(y(t))⎟│    = 0
#                                  ⎝dt      ⎠│t=0

# %%
ics = {y(0): 0, y(t).diff(t).subs(t, 0): 1}
ics
# Out:
# ⎧         ⎛d       ⎞│      ⎫
# ⎨y(0): 0, ⎜──(y(t))⎟│   : 1⎬
# ⎩         ⎝dt      ⎠│t=0   ⎭

# %%
L_edo_4 = L_edo_3.subs(ics)

Y_sol = sympy.solve(L_edo_4, Y)
Y_sol
# Out:
# ⎡    1     ⎤
# ⎢──────────⎥
# ⎢ 2        ⎥
# ⎣s  + s - 1⎦

# %%
y_sol = sympy.inverse_laplace_transform(Y_sol[0], s, t)
y_sol
# Out:
#                 -t⋅(1 + √5)
#                 ────────────
#    ⎛ √5⋅t    ⎞       2
# √5⋅⎝ℯ     - 1⎠⋅ℯ
# ────────────────────────────
#              5

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1Kvc3_V9KdB5Cw6MXPK6bDtwuA7fvwDSn" alt="" width="400" >

# %%
t = sympy.symbols("t", positive=True)
y = sympy.Function("y")

# simbolos adicionales.
s, Y = sympy.symbols("s, Y", real=True)

# Defino la ecuación
edo = y(t).diff(t, t) - 3*y(t).diff(t) + 8*y(t)- y(t)**2*sympy.exp(-2*t)
sympy.Eq(edo,0)
# Out:
#                                         2
#    2     -2⋅t              d           d
# - y (t)⋅ℯ     + 8⋅y(t) - 3⋅──(y(t)) + ───(y(t)) = 0
#                            dt           2
#                                       dt

# %%
s, Y = sympy.symbols("s, Y", real=True)

# %%
L_edo = sympy.laplace_transform(edo, t, s)
sympy.Eq(L_edo,0)
# Out:
#  2
# s ⋅LaplaceTransform(y(t), t, s) + s⋅LaplaceTransform(y(t), t, s) - s⋅y(0) - La
#
#
#               ⎛ 2     -2⋅t      ⎞                                           ⎛d
# placeTransform⎝y (t)⋅ℯ    , t, s⎠ + 8⋅LaplaceTransform(y(t), t, s) - y(0) - ⎜─
#                                                                             ⎝d
#
#        ⎞│
# ─(y(t))⎟│    = 0
# t      ⎠│t=0

# %%
def laplace_transform_derivatives(e):
    """
    Evalua las transformadas de Laplace de derivadas de funciones sin evaluar.
    """
    if isinstance(e, sympy.LaplaceTransform):
        if isinstance(e.args[0], sympy.Derivative):
            d, t, s = e.args 
            n = len(d.args) - 1
            return ((s**n) * sympy.LaplaceTransform(d.args[0], t, s) -
                    sum([s**(n-i) * sympy.diff(d.args[0], t, i-1).subs(t, 0)
                         for i in range(1, n+1)]))
        
    if isinstance(e, (sympy.Add, sympy.Mul)):
        t = type(e) 
        return t(*[laplace_transform_derivatives(arg) for arg in e.args])
    
    return e

# %%
L_edo_2 = laplace_transform_derivatives(L_edo)
sympy.Eq(L_edo_2,0)
# Out:
#  2
# s ⋅LaplaceTransform(y(t), t, s) + s⋅LaplaceTransform(y(t), t, s) - s⋅y(0) - La
#
#
#               ⎛ 2     -2⋅t      ⎞                                           ⎛d
# placeTransform⎝y (t)⋅ℯ    , t, s⎠ + 8⋅LaplaceTransform(y(t), t, s) - y(0) - ⎜─
#                                                                             ⎝d
#
#        ⎞│
# ─(y(t))⎟│    = 0
# t      ⎠│t=0

# %%
L_edo_3 = L_edo_2.subs(sympy.laplace_transform(y(t), t, s), Y)
sympy.Eq(L_edo_3,0)
# Out:
#    2                                        ⎛ 2     -2⋅t      ⎞          ⎛d
# Y⋅s  + Y⋅s + 8⋅Y - s⋅y(0) - LaplaceTransform⎝y (t)⋅ℯ    , t, s⎠ - y(0) - ⎜──(y
#                                                                          ⎝dt
#
#     ⎞│
# (t))⎟│    = 0
#     ⎠│t=0

# %%
ics = {y(0): 0, y(t).diff(t).subs(t, 0): -0}
ics
# Out:
# ⎧         ⎛d       ⎞│      ⎫
# ⎨y(0): 0, ⎜──(y(t))⎟│   : 0⎬
# ⎩         ⎝dt      ⎠│t=0   ⎭

# %%
L_edo_4 = L_edo_3.subs(ics)

Y_sol = sympy.solve(L_edo_4, Y)
Y_sol
# Out:
# ⎡                ⎛ 2     -2⋅t      ⎞⎤
# ⎢LaplaceTransform⎝y (t)⋅ℯ    , t, s⎠⎥
# ⎢───────────────────────────────────⎥
# ⎢              2                    ⎥
# ⎣             s  + s + 8            ⎦

# %%
y_sol = sympy.inverse_laplace_transform(Y_sol[0], s, t)
y_sol
# Out:
#                        ⎛                ⎛ 2     -2⋅t      ⎞            ⎞
#                        ⎜LaplaceTransform⎝y (t)⋅ℯ    , t, s⎠            ⎟
# InverseLaplaceTransform⎜───────────────────────────────────, s, t, None⎟
#                        ⎜              2                                ⎟
#                        ⎝             s  + s + 8                        ⎠

# %% [markdown]
# #### Referencias
#
# [1]	Upct.es. [Online]. Available: https://www.dmae.upct.es/~fperiago/apuntes_docencia/tema8.pdf. [Accessed: 09-Oct-2022].
#
#
# [2]	Edu.ar. [Online]. Available: http://www.unsam.edu.ar/escuelas/ciencia/alumnos/matematica_guia/apunte-4%C2%B0parte.pdf. [Accessed: 09-Oct-2022].
#
#
# [3]	“Transformada inversa de Laplace,” Ehu.es. [Online]. Available: http://www.sc.ehu.es/sbweb/fisica3/simbolico/laplace/laplace_1.html. [Accessed: 09-Oct-2022].
#
#
# [4]	“Ejemplos Transformada Inversa de Laplace,” UdeA Sytes, 24-May-2016. [Online]. Available: https://udeasytes.wordpress.com/ecuaciones/clases/semana-10-transformada-inversa-de-laplace-y-solucion-a-sli/ejemplos-transformada-inversa-de-laplace/. [Accessed: 09-Oct-2022].
